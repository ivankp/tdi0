# %%
import pandas
import matplotlib.pyplot as plt

# %%
df = pandas.read_json('bgg_data_clean.json',orient='split')
df
# Out:
#         year  age num_players              duration  \
# 387     2000   10      [3, 7]    [45.0, 45.0, 45.0]
# 475     2000   12      [2, 5]    [90.0, 45.0, 90.0]
# 478     2000   10      [2, 8]    [60.0, 20.0, 60.0]
# 481     2000   12      [2, 4]    [60.0, 60.0, 60.0]
# 490     2000   12      [2, 6]    [60.0, 60.0, 60.0]
# ...      ...  ...         ...                   ...
# 339031  2021   12      [2, 5]    [50.0, 50.0, 50.0]
# 339592  2021   10      [2, 6]    [45.0, 20.0, 45.0]
# 340909  2021   14      [1, 2]    [30.0, 20.0, 30.0]
# 341284  2021   14      [1, 4]  [120.0, 90.0, 120.0]
# 341530  2021    8      [1, 6]    [20.0, 20.0, 20.0]
#
#                                                 mechanics  \
# 387                                     [Hand Management]
# 475     [Auction, Card Drafting, Hand Management, Netw...
# 478     [Action Drafting, Card Drafting, Drafting, Los...
# 481     [Area Majority / Influence, Dice Rolling, Hand...
# ...

# %%
df['year'].plot.hist(bins=32,range=(1990,2022))
ax = plt.gca()
ax.set_ylabel('Number of released games / year')
ax.set_xlabel('year')
plt.savefig('ngames_1990.png')
